# %%
import os, time,json
import tmdbsimple as tmdb 
FOLDER = "Data/"
os.makedirs(FOLDER, exist_ok=True)
os.listdir(FOLDER)
from tqdm.notebook import tqdm_notebook
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd 
import numpy as np
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
from sqlalchemy_utils import create_database, database_exists

# %%
# Install tmdbsimple (only need to run once)
# !pip install tmdbsimple
# Out:
# Requirement already satisfied: tmdbsimple in c:\users\alexander\anaconda3\envs\dojo-env\lib\site-packages (2.9.1)
# Requirement already satisfied: requests in c:\users\alexander\anaconda3\envs\dojo-env\lib\site-packages (from tmdbsimple) (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\alexander\anaconda3\envs\dojo-env\lib\site-packages (from requests->tmdbsimple) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alexander\anaconda3\envs\dojo-env\lib\site-packages (from requests->tmdbsimple) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\alexander\anaconda3\envs\dojo-env\lib\site-packages (from requests->tmdbsimple) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alexander\anaconda3\envs\dojo-env\lib\site-packages (from requests->tmdbsimple) (2022.9.24)

# %%
import json
with open('/Users/Alexander/.secret/tmdb_api.json', 'r') as f:
    login = json.load(f)
## Display the keys of the loaded dict
login.keys()
# Out:
# dict_keys(['api-key'])

# %%
import tmdbsimple as tmdb
tmdb.API_KEY =  login['api-key']

# %%
connection = "mysql+pymysql://root:root@localhost/movies"

# %%
engine = create_engine(connection)

# %%
# Check if the database exists. If not, create it.
if database_exists(connection) == False:
    create_database(connection)
else:
    print('The database already exists')
# Out:
# The database already exists

# %%
df00= pd.read_csv('Data/final_tmdb_data_2000.csv.gz')

# %%
df01= pd.read_csv('Data/final_tmdb_data_2001.csv.gz')

# %%
title_b = pd.read_csv('Data/title_basics.csv.gz')

# %%
title_b
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# 3      tt0088751     movie                                  The Naked Monster
# 4      tt0096056     movie                               Crime and Punishment
# ...          ...       ...                                                ...
# 83102  tt9914942     movie                             Life Without Sara Amat
# 83103  tt9915872     movie                               The Last White Witch
# 83104  tt9916170     movie                                      The Rehearsal
# 83105  tt9916190     movie                                          Safeguard
# 83106  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0     2001.0      NaN
# 1      El Tango del Viudo y Su Espejo Deformante        0     2020.0      NaN
# 2                     The Other Side of the Wind        0     2018.0      NaN
# 3                              The Naked Monster        0     2005.0      NaN
# 4                           Crime and Punishment        0     2002.0      NaN
# ...                                          ...      ...        ...      ...
# 83102                 La vida sense la Sara Amat        0     2019.0      NaN
# 83103                  My Girlfriend is a Wizard        0     2019.0      NaN
# 83104                                   O Ensaio        0     2019.0      NaN
# 83105                                  Safeguard        0     2020.0      NaN
# 83106                                   Akelarre        0     2020.0      NaN
#
#        runtimeMinutes                     genres
# 0                 118     Comedy,Fantasy,Romance
# 1                  70                      Drama
# 2                 122                      Drama
# 3                 100       Comedy,Horror,Sci-Fi
# 4                 126                      Drama
# ...               ...                        ...
# 83102              74                      Drama
# 83103              97       Comedy,Drama,Fantasy
# 83104              51                      Drama
# 83105              95  Action,Adventure,Thriller
# 83106              92              Drama,History
#
# [83107 rows x 9 columns]

# %%
title_b['genres_split'] = title_b['genres'].str.split(',')

# %%
title_b
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# 3      tt0088751     movie                                  The Naked Monster
# 4      tt0096056     movie                               Crime and Punishment
# ...          ...       ...                                                ...
# 83102  tt9914942     movie                             Life Without Sara Amat
# 83103  tt9915872     movie                               The Last White Witch
# 83104  tt9916170     movie                                      The Rehearsal
# 83105  tt9916190     movie                                          Safeguard
# 83106  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0     2001.0      NaN
# 1      El Tango del Viudo y Su Espejo Deformante        0     2020.0      NaN
# 2                     The Other Side of the Wind        0     2018.0      NaN
# 3                              The Naked Monster        0     2005.0      NaN
# 4                           Crime and Punishment        0     2002.0      NaN
# ...                                          ...      ...        ...      ...
# 83102                 La vida sense la Sara Amat        0     2019.0      NaN
# 83103                  My Girlfriend is a Wizard        0     2019.0      NaN
# 83104                                   O Ensaio        0     2019.0      NaN
# 83105                                  Safeguard        0     2020.0      NaN
# 83106                                   Akelarre        0     2020.0      NaN
#
#        runtimeMinutes                     genres  \
# 0                 118     Comedy,Fantasy,Romance
# 1                  70                      Drama
# 2                 122                      Drama
# 3                 100       Comedy,Horror,Sci-Fi
# 4                 126                      Drama
# ...               ...                        ...
# 83102              74                      Drama
# 83103              97       Comedy,Drama,Fantasy
# 83104              51                      Drama
# 83105              95  Action,Adventure,Thriller
# 83106              92              Drama,History
#
#                         genres_split
# 0         [Comedy, Fantasy, Romance]
# 1                            [Drama]
# 2                            [Drama]
# 3           [Comedy, Horror, Sci-Fi]
# 4                            [Drama]
# ...                              ...
# 83102                        [Drama]
# 83103       [Comedy, Drama, Fantasy]
# 83104                        [Drama]
# 83105  [Action, Adventure, Thriller]
# 83106               [Drama, History]
#
# [83107 rows x 10 columns]

# %%
explode_genres = title_b.explode('genres_split')
explode_genres
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# ...          ...       ...                                                ...
# 83105  tt9916190     movie                                          Safeguard
# 83105  tt9916190     movie                                          Safeguard
# 83105  tt9916190     movie                                          Safeguard
# 83106  tt9916362     movie                                              Coven
# 83106  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0     2001.0      NaN
# 0                                 Kate & Leopold        0     2001.0      NaN
# 0                                 Kate & Leopold        0     2001.0      NaN
# 1      El Tango del Viudo y Su Espejo Deformante        0     2020.0      NaN
# 2                     The Other Side of the Wind        0     2018.0      NaN
# ...                                          ...      ...        ...      ...
# 83105                                  Safeguard        0     2020.0      NaN
# 83105                                  Safeguard        0     2020.0      NaN
# 83105                                  Safeguard        0     2020.0      NaN
# 83106                                   Akelarre        0     2020.0      NaN
# 83106                                   Akelarre        0     2020.0      NaN
#
#        runtimeMinutes                     genres genres_split
# 0                 118     Comedy,Fantasy,Romance       Comedy
# 0                 118     Comedy,Fantasy,Romance      Fantasy
# 0                 118     Comedy,Fantasy,Romance      Romance
# 1                  70                      Drama        Drama
# 2                 122                      Drama        Drama
# ...               ...                        ...          ...
# 83105              95  Action,Adventure,Thriller       Action
# 83105              95  Action,Adventure,Thriller    Adventure
# 83105              95  Action,Adventure,Thriller     Thriller
# 83106              92              Drama,History        Drama
# 83106              92              Drama,History      History
#
# [155278 rows x 10 columns]

# %%
genres_split = title_b['genres'].str.split(",")

# %%
# 1. Getting List of Unique Genres
unique_genres = genres_split.explode().unique()
unique_genres
# Out:
# array(['Comedy', 'Fantasy', 'Romance', 'Drama', 'Horror', 'Sci-Fi',
#        'Mystery', 'Musical', 'Action', 'Adventure', 'Crime', 'Thriller',
#        'Music', 'Animation', 'Family', 'History', 'War', 'Biography',
#        'Sport', 'Western', 'Adult', 'Short', 'Reality-TV', 'News',
#        'Talk-Show', 'Game-Show'], dtype=object)

# %%
unique_genres = sorted(explode_genres['genres_split'].unique())
# sorted aplphabetically

# %%
# 2. Create a new title_genres table
title_genres = explode_genres[['tconst', 'genres_split']].copy()
title_genres.head(3)
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance

# %%
# 3. Create a genre mapper dictionary to replace string genres with integers
## Making the genre mapper dictionary
genre_ints = range(len(unique_genres))
genre_map = dict(zip(unique_genres, genre_ints))
genre_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %%
# Make a new dictionary with a list of unique genres as the key
# and the new iteger id as values 
genre_id_map = dict(zip(unique_genres, range(len(unique_genres))))
genre_id_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %%
# 4. Replace the string genres in title_genres with the new integer ids.
## make new integer genre_id and drop string genres
title_b['genre_id'] = title_b['genres_split'].replace(genre_map)
title_b = title_b.drop(columns='genres_split')

# %%
# 5. Convert the genre map dictionary into a dataframe.
# Manually make dataframe with named columns from from .keys and .values
genre_lookup = pd.DataFrame({'Genre_Name': genre_id_map.keys(),
                             'Genre_ID': genre_id_map.values()})
genre_lookup.head(3)
# Out:
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
